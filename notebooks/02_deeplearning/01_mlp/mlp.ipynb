# %% [markdown]
# # 👀 Multilayer perceptron (MLP)

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own multilayer perceptron on the CIFAR dataset

# %%
# Save the trained model
model.save('my_cifar10_model.keras')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1970372171.py in <cell line: 0>()
#       1 # Save the trained model
# ----> 2 model.save('my_cifar10_model.keras')
#
# NameError: name 'model' is not defined

# %% [markdown]
# Now you can load the saved model and use it to predict on new images. You would need to load your new image data and preprocess it similarly to how the training data was processed (resizing, scaling, etc.). Here's an example of how to load the model and make predictions on the existing test data, just to demonstrate the loading process:

# %%
# Load the saved model
loaded_model = models.load_model('my_cifar10_model.keras')

# Make predictions on the test data using the loaded model
predictions_on_new_data = loaded_model.predict(x_test[:5]) # Predicting on the first 5 test images as an example
predicted_classes = CLASSES[np.argmax(predictions_on_new_data, axis=-1)]

print("Predictions on the first 5 test images after loading the model:")
print(predicted_classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3487544239.py in <cell line: 0>()
#       1 # Load the saved model
# ----> 2 loaded_model = models.load_model('my_cifar10_model.keras')
#       3
#       4 # Make predictions on the test data using the loaded model
#       5 predictions_on_new_data = loaded_model.predict(x_test[:5]) # Predicting on the first 5 test images as an example
#
# NameError: name 'models' is not defined

# %% [markdown]
# First, make sure you have run the cells that define the model and save it. Then, you can load the saved model.

# %%
# Load the saved model
loaded_model = models.load_model('my_cifar10_model.keras')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-609256996.py in <cell line: 0>()
#       1 # Load the saved model
# ----> 2 loaded_model = models.load_model('my_cifar10_model.keras')
#
# NameError: name 'models' is not defined

# %% [markdown]
# Now, you can use the loaded model to predict on new images. Replace `new_images` with your actual new image data. Make sure your new images are preprocessed in the same way as the training data (e.g., scaled to 0-1).

# %%
# Assuming 'new_images' is your preprocessed data for new images
predictions_on_new_data = loaded_model.predict(x_test[:5]) # Using the first 5 test images as an example
predicted_classes = CLASSES[np.argmax(predictions_on_new_data, axis=-1)]

print("Predictions on the first 5 test images after loading the model:")
print(predicted_classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3479150777.py in <cell line: 0>()
#       1 # Assuming 'new_images' is your preprocessed data for new images
# ----> 2 predictions_on_new_data = loaded_model.predict(x_test[:5]) # Using the first 5 test images as an example
#       3 predicted_classes = CLASSES[np.argmax(predictions_on_new_data, axis=-1)]
#       4
#       5 print("Predictions on the first 5 test images after loading the model:")
#
# NameError: name 'loaded_model' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models, optimizers, utils, datasets
from IPython.display import display

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
NUM_CLASSES = 10

# %% [markdown]
# ## 1. Prepare the Data <a name="prepare"></a>

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3674792063.py in <cell line: 0>()
# ----> 1 (x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
#
# NameError: name 'datasets' is not defined

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

y_train = utils.to_categorical(y_train, NUM_CLASSES)
y_test = utils.to_categorical(y_test, NUM_CLASSES)

# %%
display(x_train[:10])
print(y_train[:10])

# %% [markdown]
# ## 2. Build the model <a name="build"></a>

# %%
input_layer = layers.Input((32, 32, 3))

x = layers.Flatten()(input_layer)
x = layers.Dense(200, activation="relu")(x)
x = layers.Dense(150, activation="relu")(x)

output_layer = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = models.Model(input_layer, output_layer)

model.summary()

# %% [markdown]
# ## 3. Train the model <a name="train"></a>

# %%
opt = optimizers.Adam(learning_rate=0.0005)
model.compile(
    loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"]
)

# %%
model.fit(x_train, y_train, batch_size=32, epochs=10, shuffle=True)

# %% [markdown]
# ## 4. Evaluation <a name="evaluate"></a>

# %%
model.evaluate(x_test, y_test)

# %%
CLASSES = np.array(
    [
        "airplane",
        "automobile",
        "bird",
        "cat",
        "deer",
        "dog",
        "frog",
        "horse",
        "ship",
        "truck",
    ]
)

preds = model.predict(x_test)
preds_single = CLASSES[np.argmax(preds, axis=-1)]
actual_single = CLASSES[np.argmax(y_test, axis=-1)]

# %%
n_to_show = 10
indices = np.random.choice(range(len(x_test)), n_to_show)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i, idx in enumerate(indices):
    img = x_test[idx]
    ax = fig.add_subplot(1, n_to_show, i + 1)
    ax.axis("off")
    ax.text(
        0.5,
        -0.35,
        "pred = " + str(preds_single[idx]),
        fontsize=10,
        ha="center",
        transform=ax.transAxes,
    )
    ax.text(
        0.5,
        -0.7,
        "act = " + str(actual_single[idx]),
        fontsize=10,
        ha="center",
        transform=ax.transAxes,
    )
    ax.imshow(img)
